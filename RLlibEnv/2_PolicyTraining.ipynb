# %% [markdown]
# **Note**: When running this notebook on SageMaker Studio, you should make sure the 'SageMaker JumpStart Tensorflow 1.0' image/kernel is used. You can run run all cells at once or step through the notebook.
# # Policy Training
#
# This notebook outlines the steps involved in building and deploying a Battlesnake model using Ray RLlib and TensorFlow on Amazon SageMaker.
#
# Library versions currently in use:  TensorFlow 2.1, Ray RLlib 0.8.2
#
# The model is first trained using multi-agent PPO, and then deployed to a managed _TensorFlow Serving_ SageMaker endpoint that can be used for inference.

# %%
import sagemaker
from sagemaker.rl import RLEstimator, RLToolkit
import boto3
import botocore
import json

# %%
with open("../stack_outputs.json") as f:
    info = json.load(f)

# %% [markdown]
# ## Initialise sagemaker
# We need to define several parameters prior to running the training job.

# %%
sm_session = sagemaker.session.Session()
s3_bucket = info["S3Bucket"]

s3_output_path = 's3://{}/'.format(s3_bucket)
print("S3 bucket path: {}".format(s3_output_path))
# Out:
# S3 bucket path: s3://sagemaker-soln-bs-2-snake-bucket/

# %%
job_name_prefix = info["SolutionPrefix"]+'-job-rllib'

role = info["SageMakerIamRoleArn"]
print(role)
# Out:
# arn:aws:iam::272626058261:role/sagemaker-soln-bs-2-us-west-2-nb-role

# %% [markdown]
# Change local_mode to True if you want to do local training within this Notebook instance

# %%
local_mode = False

if local_mode:
    instance_type = 'local'
else:
    instance_type = info["SagemakerTrainingInstanceType"]
    
# If training locally, do some Docker housekeeping..
if local_mode:
    # !/bin/bash ./common/setup.sh

# %% [markdown]
# # Train your model here

# %%
region = sm_session.boto_region_name
device = "cpu"
image_name = '462105765813.dkr.ecr.{region}.amazonaws.com/sagemaker-rl-ray-container:ray-0.8.2-tf-{device}-py36'.format(region=region, device=device)

# %%
# %%time

# Define and execute our training job
# Adjust hyperparameters and train_instance_count accordingly

metric_definitions =  [
    {'Name': 'training_iteration', 'Regex': 'training_iteration: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    {'Name': 'episodes_total', 'Regex': 'episodes_total: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    {'Name': 'num_steps_trained', 'Regex': 'num_steps_trained: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    {'Name': 'timesteps_total', 'Regex': 'timesteps_total: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'training_iteration', 'Regex': 'training_iteration: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},

    {'Name': 'episode_reward_max', 'Regex': 'episode_reward_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    {'Name': 'episode_reward_mean', 'Regex': 'episode_reward_mean: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    {'Name': 'episode_reward_min', 'Regex': 'episode_reward_min: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    
    {'Name': 'episode_len_max', 'Regex': 'episode_len_mean: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    {'Name': 'episode_len_mean', 'Regex': 'episode_len_mean: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 
    {'Name': 'episode_len_min', 'Regex': 'episode_len_mean: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}, 

    {'Name': 'best_snake_episode_len_max', 'Regex': 'best_snake_episode_len_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'worst_snake_episode_len_max', 'Regex': 'worst_snake_episode_len_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},

    {'Name': 'Snake_hit_wall_max', 'Regex': 'Snake_hit_wall_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'Snake_was_eaten_max', 'Regex': 'Snake_was_eaten_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'Killed_another_snake_max', 'Regex': 'Killed_another_snake_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'Snake_hit_body_max', 'Regex': 'Snake_hit_body_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'Starved_max', 'Regex': 'Starved_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'Forbidden_move_max', 'Regex': 'Forbidden_move_max: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}
] 

algorithm = "PPO"
map_size = 11
num_agents = 5
additional_config = {
    'lambda': 0.90,
    'gamma': 0.999,
    'kl_coeff': 0.2,
    'clip_rewards': True,
    'vf_clip_param': 175.0,
    'train_batch_size': 9216,
    'sample_batch_size': 96,
    'sgd_minibatch_size': 256,
    'num_sgd_iter': 3,
    'lr': 5.0e-4,
}

estimator = RLEstimator(entry_point="train-mabs.py",
                        source_dir='training/training_src',
                        dependencies=["training/common/sagemaker_rl", "inference/inference_src/", "../BattlesnakeGym/"],
                        image_name=image_name,
                        role=role,
                        train_instance_type=instance_type,
                        train_instance_count=1,
                        output_path=s3_output_path,
                        base_job_name=job_name_prefix,
                        metric_definitions=metric_definitions,
                        hyperparameters={
                            # See train-mabs.py to add additional hyperparameters
                            # Also see ray_launcher.py for the rl.training.* hyperparameters
                            # number of iterations (3 iters ~ 2 mins)
                            "num_iters": 2,
                            # number of snakes in the gym
                            "num_agents": num_agents,

                            "iterate_map_size": False,
                            "map_size": map_size,
                            "algorithm": algorithm,
                            "additional_configs": additional_config,
                            "use_heuristics_action_masks": False
                        },
                        image_uri='462105765813.dkr.ecr.us-west-2.amazonaws.com/sagemaker-rl-ray-container:ray-0.8.2-tf-cpu-py36'
                    )

estimator.fit()

job_name = estimator.latest_training_job.job_name
print("Training job: %s" % job_name)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# image_name has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2022-06-18 10:08:04 Starting - Starting the training job...
# 2022-06-18 10:08:27 Starting - Preparing the instances for trainingProfilerReport-1655546883: InProgress
# ......
# 2022-06-18 10:09:27 Downloading - Downloading input data...
# 2022-06-18 10:09:47 Training - Downloading the training image..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
#
# 2022-06-18 10:10:27 Training - Training image download completed. Training in progress.2022-06-18 10:10:23,845 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-06-18 10:10:23,855 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-06-18 10:10:24,076 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python3 -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting array2gif
#   Downloading array2gif-1.0.4-py3-none-any.whl (7.8 kB)
# Collecting mxboard
#   Downloading mxboard-0.1.0-py3-none-any.whl (47 kB)
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from array2gif->-r requirements.txt (line 1)) (1.18.1)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from mxboard->-r requirements.txt (line 2)) (3.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from mxboard->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from mxboard->-r requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym->-r requirements.txt (line 3)) (2.22.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->-r requirements.txt (line 3)) (1.5.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.0.0->mxboard->-r requirements.txt (line 2)) (46.1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym->-r requirements.txt (line 3)) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym->-r requirements.txt (line 3)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym->-r requirements.txt (line 3)) (1.25.9)
# Building wheels for collected packages: battlesnake-gym
#   Building wheel for battlesnake-gym (setup.py): started
#   Building wheel for battlesnake-gym (setup.py): finished with status 'done'
#   Created wheel for battlesnake-gym: filename=battlesnake_gym-0.1.dev0-py3-none-any.whl size=16942 sha256=bc2b3427a853e8c273a9ada87975568f680dc15e2f476cd242915f0ae50f26e7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-289_1r1p/wheels/95/c1/85/65aaf48b35aba88c6e896d2fd04a4b69f1cee0d81ea32993ca
# Successfully built battlesnake-gym
# Installing collected packages: array2gif, mxboard, battlesnake-gym
# Successfully installed array2gif-1.0.4 battlesnake-gym-0.1.dev0 mxboard-0.1.0
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# 2022-06-18 10:10:26,737 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-06-18 10:10:26,762 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-06-18 10:10:26,778 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-06-18 10:10:26,789 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {
#         "sagemaker_estimator": "RLEstimator"
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "additional_configs": {
#             "lambda": 0.9,
#             "gamma": 0.999,
#             "kl_coeff": 0.2,
#             "clip_rewards": true,
#             "vf_clip_param": 175.0,
#             "train_batch_size": 9216,
#             "sample_batch_size": 96,
#             "sgd_minibatch_size": 256,
#             "num_sgd_iter": 3,
#             "lr": 0.0005
#         },
#         "algorithm": "PPO",
#         "iterate_map_size": false,
#         "map_size": 11,
#         "num_agents": 5,
#         "num_iters": 2,
#         "use_heuristics_action_masks": false
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-soln-bs-2-snake-bucket/sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515/source/sourcedir.tar.gz",
#     "module_name": "train-mabs",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train-mabs.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"additional_configs":{"clip_rewards":true,"gamma":0.999,"kl_coeff":0.2,"lambda":0.9,"lr":0.0005,"num_sgd_iter":3,"sample_batch_size":96,"sgd_minibatch_size":256,"train_batch_size":9216,"vf_clip_param":175.0},"algorithm":"PPO","iterate_map_size":false,"map_size":11,"num_agents":5,"num_iters":2,"use_heuristics_action_masks":false}
# SM_USER_ENTRY_POINT=train-mabs.py
# SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train-mabs
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-soln-bs-2-snake-bucket/sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"additional_configs":{"clip_rewards":true,"gamma":0.999,"kl_coeff":0.2,"lambda":0.9,"lr":0.0005,"num_sgd_iter":3,"sample_batch_size":96,"sgd_minibatch_size":256,"train_batch_size":9216,"vf_clip_param":175.0},"algorithm":"PPO","iterate_map_size":false,"map_size":11,"num_agents":5,"num_iters":2,"use_heuristics_action_masks":false},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-soln-bs-2-snake-bucket/sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515/source/sourcedir.tar.gz","module_name":"train-mabs","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train-mabs.py"}
# SM_USER_ARGS=["--additional_configs","clip_rewards=True,gamma=0.999,kl_coeff=0.2,lambda=0.9,lr=0.0005,num_sgd_iter=3,sample_batch_size=96,sgd_minibatch_size=256,train_batch_size=9216,vf_clip_param=175.0","--algorithm","PPO","--iterate_map_size","False","--map_size","11","--num_agents","5","--num_iters","2","--use_heuristics_action_masks","False"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_ADDITIONAL_CONFIGS={"clip_rewards":true,"gamma":0.999,"kl_coeff":0.2,"lambda":0.9,"lr":0.0005,"num_sgd_iter":3,"sample_batch_size":96,"sgd_minibatch_size":256,"train_batch_size":9216,"vf_clip_param":175.0}
# SM_HP_ALGORITHM=PPO
# SM_HP_ITERATE_MAP_SIZE=false
# SM_HP_MAP_SIZE=11
# SM_HP_NUM_AGENTS=5
# SM_HP_NUM_ITERS=2
# SM_HP_USE_HEURISTICS_ACTION_MASKS=false
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# Invoking script with the following command:
# /usr/bin/python3 -m train-mabs --additional_configs clip_rewards=True,gamma=0.999,kl_coeff=0.2,lambda=0.9,lr=0.0005,num_sgd_iter=3,sample_batch_size=96,sgd_minibatch_size=256,train_batch_size=9216,vf_clip_param=175.0 --algorithm PPO --iterate_map_size False --map_size 11 --num_agents 5 --num_iters 2 --use_heuristics_action_masks False
# 2022-06-18 10:10:30,584#011INFO resource_spec.py:212 -- Starting Ray with 7.13 GiB memory available for workers and up to 3.57 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2022-06-18 10:10:31,039#011INFO services.py:1078 -- View the Ray dashboard at #033#033localhost:8265#033#033
# No checkpoint path specified. Training from scratch.
# Important! Ray with version <=7.2 may report "Did not find checkpoint file" even if the experiment is actually restored successfully. If restoration is expected, please check "training_iteration" in the experiment info to confirm.
# == Status ==
# Memory usage on this node: 2.1/15.4 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 4/4 CPUs, 0/0 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+-------+
# | Trial name                            | status   | loc   |
# |---------------------------------------+----------+-------|
# | PPO_MultiAgentBattlesnake-v1_e2cd9a20 | RUNNING  |       |
# +---------------------------------------+----------+-------+
# 2022-06-18 10:10:32,994#011WARNING worker.py:1058 -- The dashboard on node ip-10-0-78-65.us-west-2.compute.internal failed with the following error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1062, in create_server
#     sock.bind(sa)
# OSError: [Errno 99] Cannot assign requested address
# During handling of the above exception, another exception occurred:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/dashboard/dashboard.py", line 920, in <module>
#     dashboard.run()
#   File "/usr/local/lib/python3.6/dist-packages/ray/dashboard/dashboard.py", line 368, in run
#     aiohttp.web.run_app(self.app, host=self.host, port=self.port)
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web.py", line 433, in run_app
#     reuse_port=reuse_port))
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 484, in run_until_complete
#     return future.result()
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web.py", line 359, in _run_app
#     await site.start()
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web_runner.py", line 104, in start
#     reuse_port=self._reuse_port)
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1066, in create_server
#     % (sa, err.strerror.lower()))
# OSError: [Errno 99] error while attempting to bind on address ('::1', 8265, 0, 0): cannot assign requested address
# #033#033(pid=116)#033 2022-06-18 10:10:35,107#011INFO trainer.py:420 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# #033#033(pid=116)#033 2022-06-18 10:10:35,109#011INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=116)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=116)#033   obj = yaml.load(type_)
# #033#033(pid=116)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=116)#033   obj = yaml.load(type_)
# #033#033(pid=116)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=116)#033   obj = yaml.load(type_)
# #033#033(pid=116)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=116)#033   obj = yaml.load(type_)
# #033#033(pid=116)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=116)#033   obj = yaml.load(type_)
# #033#033(pid=114)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=114)#033   obj = yaml.load(type_)
# #033#033(pid=115)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=115)#033   obj = yaml.load(type_)
# #033#033(pid=117)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=117)#033   obj = yaml.load(type_)
# #033#033(pid=115)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=115)#033   obj = yaml.load(type_)
# #033#033(pid=114)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=114)#033   obj = yaml.load(type_)
# #033#033(pid=117)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=117)#033   obj = yaml.load(type_)
# #033#033(pid=115)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=115)#033   obj = yaml.load(type_)
# #033#033(pid=114)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=114)#033   obj = yaml.load(type_)
# #033#033(pid=117)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=117)#033   obj = yaml.load(type_)
# #033#033(pid=117)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=117)#033   obj = yaml.load(type_)
# #033#033(pid=115)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=115)#033   obj = yaml.load(type_)
# #033#033(pid=114)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=114)#033   obj = yaml.load(type_)
# #033#033(pid=114)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=114)#033   obj = yaml.load(type_)
# #033#033(pid=117)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=117)#033   obj = yaml.load(type_)
# #033#033(pid=115)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=115)#033   obj = yaml.load(type_)
# #033#033(pid=116)#033 2022-06-18 10:11:19,722#011INFO trainable.py:178 -- _setup took 44.615 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# Result for PPO_MultiAgentBattlesnake-v1_e2cd9a20:
#   best_snake_episode_len_max: 15
#   custom_metrics:
#     Forbidden_move_max: 10
#     Forbidden_move_mean: 3.8624239588207767
#     Forbidden_move_min: 0
#     Killed_another_snake_max: 2
#     Killed_another_snake_mean: 0.11839026672905943
#     Killed_another_snake_min: 0
#     Snake_hit_body_max: 4
#     Snake_hit_body_mean: 0.2484791764155358
#     Snake_hit_body_min: 0
#     Snake_hit_wall_max: 7
#     Snake_hit_wall_mean: 1.3631258773982218
#     Snake_hit_wall_min: 0
#     Snake_was_eaten_max: 8
#     Snake_was_eaten_mean: 0.31118390266729057
#     Snake_was_eaten_min: 0
#     Starved_max: 0
#     Starved_mean: 0.0
#     Starved_min: 0
#     policy0_max_len_max: 13
#     policy0_max_len_mean: 2.220402433317735
#     policy0_max_len_min: 0
#     policy1_max_len_max: 14
#     policy1_max_len_mean: 2.220402433317735
#     policy1_max_len_min: 0
#     policy2_max_len_max: 14
#     policy2_max_len_mean: 2.2779597566682264
#     policy2_max_len_min: 0
#     policy3_max_len_max: 12
#     policy3_max_len_mean: 2.227889564810482
#     policy3_max_len_min: 0
#     policy4_max_len_max: 15
#     policy4_max_len_mean: 2.265325222274216
#     policy4_max_len_min: 0
#   date: 2022-06-18_10-13-03
#   done: false
#   episode_len_max: 15
#   episode_len_mean: 4.308844174075807
#   episode_len_min: 1
#   episode_reward_max: 41.0
#   episode_reward_mean: 11.211979410388395
#   episode_reward_min: 0.0
#   episodes_this_iter: 2137
#   episodes_total: 2137
#   experiment_id: 137f96a513704f0984e71f3ba842c59b
#   experiment_tag: '0'
#   hostname: ip-10-0-78-65.us-west-2.compute.internal
#   info:
#     grad_time_ms: 22922.028
#     learner:
#       policy_0:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3742830753326416
#         entropy_coeff: 0.0
#         kl: 0.010588172823190689
#         policy_loss: -0.015616748481988907
#         total_loss: 1.5547242164611816
#         vf_explained_var: 0.17764857411384583
#         vf_loss: 1.5682233572006226
#       policy_1:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.366420030593872
#         entropy_coeff: 0.0
#         kl: 0.010946664959192276
#         policy_loss: -0.01899668760597706
#         total_loss: 1.3812333345413208
#         vf_explained_var: 0.2040063887834549
#         vf_loss: 1.398040771484375
#       policy_2:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3796137571334839
#         entropy_coeff: 0.0
#         kl: 0.005434421822428703
#         policy_loss: -0.013145288452506065
#         total_loss: 1.5774707794189453
#         vf_explained_var: 0.17769595980644226
#         vf_loss: 1.589529037475586
#       policy_3:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3743667602539062
#         entropy_coeff: 0.0
#         kl: 0.009466326795518398
#         policy_loss: -0.01357279159128666
#         total_loss: 1.49855637550354
#         vf_explained_var: 0.15672391653060913
#         vf_loss: 1.5102359056472778
#       policy_4:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3426222801208496
#         entropy_coeff: 0.0
#         kl: 0.012503044679760933
#         policy_loss: -0.018966959789395332
#         total_loss: 1.4794856309890747
#         vf_explained_var: 0.19688592851161957
#         vf_loss: 1.4959518909454346
#     load_time_ms: 3255.412
#     num_steps_sampled: 9216
#     num_steps_trained: 9216
#     sample_time_ms: 44253.467
#     update_time_ms: 27934.121
#   iterations_since_restore: 1
#   node_ip: 10.0.78.65
#   num_healthy_workers: 3
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 71.94500000000001
#     ram_util_percent: 32.98785714285714
#   pid: 116
#   policy_reward_max:
#     policy_0: 13.0
#     policy_1: 14.0
#     policy_2: 14.0
#     policy_3: 12.0
#     policy_4: 15.0
#   policy_reward_mean:
#     policy_0: 2.220402433317735
#     policy_1: 2.220402433317735
#     policy_2: 2.2779597566682264
#     policy_3: 2.227889564810482
#     policy_4: 2.265325222274216
#   policy_reward_min:
#     policy_0: 0.0
#     policy_1: 0.0
#     policy_2: 0.0
#     policy_3: 0.0
#     policy_4: 0.0
#   sampler_perf:
#     mean_env_wait_ms: 2.4467424832512306
#     mean_inference_ms: 7.930856012531221
#     mean_processing_ms: 3.1955769581857467
#   time_since_restore: 100.41222667694092
#   time_this_iter_s: 100.41222667694092
#   time_total_s: 100.41222667694092
#   timestamp: 1655547183
#   timesteps_since_restore: 9216
#   timesteps_this_iter: 9216
#   timesteps_total: 9216
#   training_iteration: 1
#   trial_id: e2cd9a20
#   worst_snake_episode_len_max: 12
#
# == Status ==
# Memory usage on this node: 6.3/15.4 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 4/4 CPUs, 0/0 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+----------------+----------+------------------+------+--------+
# | Trial name                            | status   | loc            |   reward |   total time (s) |   ts |   iter |
# |---------------------------------------+----------+----------------+----------+------------------+------+--------|
# | PPO_MultiAgentBattlesnake-v1_e2cd9a20 | RUNNING  | 10.0.78.65:116 |   11.212 |          100.412 | 9216 |      1 |
# +---------------------------------------+----------+----------------+----------+------------------+------+--------+
# Result for PPO_MultiAgentBattlesnake-v1_e2cd9a20:
#   best_snake_episode_len_max: 14
#   custom_metrics:
#     Forbidden_move_max: 9
#     Forbidden_move_mean: 3.7953890489913547
#     Forbidden_move_min: 0
#     Killed_another_snake_max: 3
#     Killed_another_snake_mean: 0.1287223823246878
#     Killed_another_snake_min: 0
#     Snake_hit_body_max: 6
#     Snake_hit_body_mean: 0.2680115273775216
#     Snake_hit_body_min: 0
#     Snake_hit_wall_max: 8
#     Snake_hit_wall_mean: 1.3751200768491836
#     Snake_hit_wall_min: 0
#     Snake_was_eaten_max: 8
#     Snake_was_eaten_mean: 0.2973102785782901
#     Snake_was_eaten_min: 0
#     Starved_max: 0
#     Starved_mean: 0.0
#     Starved_min: 0
#     policy0_max_len_max: 12
#     policy0_max_len_mean: 2.2656099903938522
#     policy0_max_len_min: 0
#     policy1_max_len_max: 14
#     policy1_max_len_mean: 2.344380403458213
#     policy1_max_len_min: 0
#     policy2_max_len_max: 12
#     policy2_max_len_mean: 2.3285302593659942
#     policy2_max_len_min: 0
#     policy3_max_len_max: 12
#     policy3_max_len_mean: 2.3338136407300674
#     policy3_max_len_min: 0
#     policy4_max_len_max: 13
#     policy4_max_len_mean: 2.3376560999039384
#     policy4_max_len_min: 0
#   date: 2022-06-18_10-14-00
#   done: true
#   episode_len_max: 14
#   episode_len_mean: 4.428434197886648
#   episode_len_min: 1
#   episode_reward_max: 39.0
#   episode_reward_mean: 11.609990393852065
#   episode_reward_min: 1.0
#   episodes_this_iter: 2082
#   episodes_total: 4219
#   experiment_id: 137f96a513704f0984e71f3ba842c59b
#   experiment_tag: '0'
#   hostname: ip-10-0-78-65.us-west-2.compute.internal
#   info:
#     grad_time_ms: 17982.16
#     learner:
#       policy_0:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.335059642791748
#         entropy_coeff: 0.0
#         kl: 0.016251660883426666
#         policy_loss: -0.03209741413593292
#         total_loss: 1.4624652862548828
#         vf_explained_var: 0.3056333363056183
#         vf_loss: 1.4913123846054077
#       policy_1:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.349655032157898
#         entropy_coeff: 0.0
#         kl: 0.01786927320063114
#         policy_loss: -0.03594322130084038
#         total_loss: 1.5996439456939697
#         vf_explained_var: 0.3066965639591217
#         vf_loss: 1.6320134401321411
#       policy_2:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3552461862564087
#         entropy_coeff: 0.0
#         kl: 0.015402768738567829
#         policy_loss: -0.03141172230243683
#         total_loss: 1.6042054891586304
#         vf_explained_var: 0.30135369300842285
#         vf_loss: 1.63253653049469
#       policy_3:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3385356664657593
#         entropy_coeff: 0.0
#         kl: 0.015496624633669853
#         policy_loss: -0.02957155369222164
#         total_loss: 1.5777722597122192
#         vf_explained_var: 0.2886619567871094
#         vf_loss: 1.6042444705963135
#       policy_4:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.2863872051239014
#         entropy_coeff: 0.0
#         kl: 0.018910430371761322
#         policy_loss: -0.034421976655721664
#         total_loss: 1.5380007028579712
#         vf_explained_var: 0.31386855244636536
#         vf_loss: 1.5686407089233398
#     load_time_ms: 2017.135
#     num_steps_sampled: 18432
#     num_steps_trained: 18432
#     sample_time_ms: 43229.205
#     update_time_ms: 13980.019
#   iterations_since_restore: 2
#   node_ip: 10.0.78.65
#   num_healthy_workers: 3
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 82.25416666666666
#     ram_util_percent: 42.201388888888886
#   pid: 116
#   policy_reward_max:
#     policy_0: 12.0
#     policy_1: 14.0
#     policy_2: 12.0
#     policy_3: 12.0
#     policy_4: 13.0
#   policy_reward_mean:
#     policy_0: 2.2656099903938522
#     policy_1: 2.344380403458213
#     policy_2: 2.3285302593659942
#     policy_3: 2.3338136407300674
#     policy_4: 2.3376560999039384
#   policy_reward_min:
#     policy_0: 0.0
#     policy_1: 0.0
#     policy_2: 0.0
#     policy_3: 0.0
#     policy_4: 0.0
#   sampler_perf:
#     mean_env_wait_ms: 2.4426387570742913
#     mean_inference_ms: 7.791741933430165
#     mean_processing_ms: 3.214552735120509
#   time_since_restore: 156.77227330207825
#   time_this_iter_s: 56.36004662513733
#   time_total_s: 156.77227330207825
#   timestamp: 1655547240
#   timesteps_since_restore: 18432
#   timesteps_this_iter: 9216
#   timesteps_total: 18432
#   training_iteration: 2
#   trial_id: e2cd9a20
#   worst_snake_episode_len_max: 12
#
# == Status ==
# Memory usage on this node: 6.3/15.4 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 4/4 CPUs, 0/0 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+----------------+----------+------------------+-------+--------+
# | Trial name                            | status   | loc            |   reward |   total time (s) |    ts |   iter |
# |---------------------------------------+----------+----------------+----------+------------------+-------+--------|
# | PPO_MultiAgentBattlesnake-v1_e2cd9a20 | RUNNING  | 10.0.78.65:116 |    11.61 |          156.772 | 18432 |      2 |
# +---------------------------------------+----------+----------------+----------+------------------+-------+--------+
# == Status ==
# Memory usage on this node: 6.3/15.4 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/0 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 TERMINATED)
# +---------------------------------------+------------+-------+----------+------------------+-------+--------+
# | Trial name                            | status     | loc   |   reward |   total time (s) |    ts |   iter |
# |---------------------------------------+------------+-------+----------+------------------+-------+--------|
# | PPO_MultiAgentBattlesnake-v1_e2cd9a20 | TERMINATED |       |    11.61 |          156.772 | 18432 |      2 |
# +---------------------------------------+------------+-------+----------+------------------+-------+--------+
# Saved model configuration.
# Saved the checkpoint file /opt/ml/output/intermediate/training/PPO_MultiAgentBattlesnake-v1_e2cd9a20_0_2022-06-18_10-10-31k61ctd9j/checkpoint_2/checkpoint-2 as /opt/ml/model/checkpoint
# Saved the checkpoint file /opt/ml/output/intermediate/training/PPO_MultiAgentBattlesnake-v1_e2cd9a20_0_2022-06-18_10-10-31k61ctd9j/checkpoint_2/checkpoint-2.tune_metadata as /opt/ml/model/checkpoint.tune_metadata
# 2022-06-18 10:14:05,655#011INFO trainer.py:420 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2022-06-18 10:14:05,663#011INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# #033#033(pid=565)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=565)#033   obj = yaml.load(type_)
# #033#033(pid=565)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=565)#033   obj = yaml.load(type_)
# #033#033(pid=565)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=565)#033   obj = yaml.load(type_)
# #033#033(pid=565)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=565)#033   obj = yaml.load(type_)
# #033#033(pid=565)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=565)#033   obj = yaml.load(type_)
# 2022-06-18 10:14:43,245#011INFO trainable.py:178 -- _setup took 37.584 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-06-18 10:14:45,538#011WARNING trainable.py:210 -- Getting current IP.
# 2022-06-18 10:14:45,539#011INFO trainable.py:416 -- Restored on 10.0.78.65 from checkpoint: /opt/ml/model/checkpoint
# 2022-06-18 10:14:45,539#011INFO trainable.py:423 -- Current state after restoring: {'_iteration': 2, '_timesteps_total': 18432, '_time_total': 156.77227330207825, '_episodes_total': 4219}
# Saved TensorFlow serving model!
# 2022-06-18 10:14:51,697 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2022-06-18 10:15:08 Uploading - Uploading generated training model
# 2022-06-18 10:15:08 Completed - Training job completed
# Training seconds: 343
# Billable seconds: 343
# Training job: sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515
# CPU times: user 1.15 s, sys: 65.4 ms, total: 1.21 s
# Wall time: 7min 22s

# %%
# Where is the model stored in S3?
estimator.model_data
# Out:
# 's3://sagemaker-soln-bs-2-snake-bucket/sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515/output/model.tar.gz'

# %% [markdown]
# # Create an endpoint to host the policy
# Firstly, we will delete the previous endpoint and model

# %%
'''
sm_client = boto3.client(service_name='sagemaker')
waiter = sm_client.get_waiter('endpoint_in_service')
waiter.wait(EndpointName=info['SagemakerEndPointName'])
try:
    sm_client.delete_endpoint(EndpointName=info['SagemakerEndPointName'])
    sm_client.delete_endpoint_config(EndpointConfigName=info['SagemakerEndPointName'])
    sm_client.delete_model(ModelName=info['SagemakerEndPointName'])
    ep_waiter = sm_client.get_waiter('endpoint_deleted')
    ep_waiter.wait(EndpointName=info['SagemakerEndPointName'])
except botocore.exceptions.ClientError:
    pass
'''
# Copy the endpoint to a central location
model_data = "s3://{}/pretrainedmodels/model.tar.gz".format(s3_bucket)
# !aws s3 cp {estimator.model_data} {model_data}

from sagemaker.tensorflow.serving import Model

model = Model(model_data=model_data,
              role=role,
              entry_point="inference.py",
              source_dir='inference/inference_src',
              framework_version='2.1.0',
              name=info['SagemakerEndPointName'],
              code_location='s3://{}//code'.format(s3_bucket)
             )

if local_mode:
    inf_instance_type = 'local'
else:
    inf_instance_type = info["SagemakerInferenceInstanceType"]

# Deploy an inference endpoint
predictor = model.deploy(initial_instance_count=1, instance_type=inf_instance_type,
                         endpoint_name=info['SagemakerEndPointName'])
# Out:
# copy: s3://sagemaker-soln-bs-2-snake-bucket/sagemaker-soln-bs-2-job-rllib-2022-06-18-10-08-03-515/output/model.tar.gz to s3://sagemaker-soln-bs-2-snake-bucket/pretrainedmodels/model.tar.gz
# The class sagemaker.tensorflow.serving.Model has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ------!

# %% [markdown]
# # Test the endpoint
#
# This example is using single observation for a 5-agent environment
# The last axis is 12 because the current MultiAgentEnv is concatenating 2 frames
# 5 agent maps + 1 food map = 6 maps total    6 maps * 2 frames = 12

# %%
import numpy as np
from time import time

state = np.zeros(shape=(1, 21, 21, 6), dtype=np.float32).tolist()

health_dict = {0: 50, 1: 50}
json = {"turn": 4,
        "board": {
                "height": 11,
                "width": 11,
                "food": [],
                "snakes": []
                },
            "you": {
                "id": "snake-id-string",
                "name": "Sneky Snek",
                "health": 90,
                "body": [{"x": 1, "y": 3}]
                }
            }

before = time()
action_mask = np.array([1, 1, 1, 1]).tolist()

action = predictor.predict({"state": state, "action_mask": action_mask,
                            "prev_action": -1, 
                           "prev_reward": -1, "seq_lens": -1,  
                           "all_health": health_dict, "json": json})
elapsed = time() - before

action_to_take = action["outputs"]["heuristisc_action"]
print("Action to take {}".format(action_to_take))
print("Inference took %.2f ms" % (elapsed*1000))
# Out:
# Action to take 1
# Inference took 677.52 ms

# %% [markdown]
# # Navigation
# - To go back to the introduction click [here](./1_Introduction.ipynb)
# - To build some heuristics click [here](./3_HeuristicsDeveloper.ipynb)
